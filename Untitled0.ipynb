# %% [markdown]
# EXP 1 : INTRODUCTION TO PYTHON
# (NAME - SAUMYA SHREE)
# (PRN - 25070123161)

# %%
x = "APPLE"
y = "ORANGE"
z = "CHERRY"
print(x,y,z)
# Out:
# APPLE ORANGE CHERRY

# %%
x,y,z = "APPLE","ORANGE","CHERRY"
print(x,y,z,sep="\n")
# Out:
# APPLE
# ORANGE
# CHERRY

# %%
x,y,z,w = 2,2.5,"Saumya",True
print(type(x),type(y),type(z),type(w),sep="\n")
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
a,b = 10,5
print("SUM =",a+b,"DIFFERENCE =",a-b,"PRODUCT =",a*b,"DIVISION =",a/b,"EXPONENT =",a**b)
# Out:
# SUM = 15 DIFFERENCE = 5 PRODUCT = 50 DIVISION = 2.0 EXPONENT = 100000

# %%
a = int(input("Enter a number ="))
b = int(input("Enter another number="))
print("SUM =",a+b,"\n","DIFFERENCE =",a-b,"\n","PRODUCT =",a*b,"\n","DIVISION =",a/b,"\n","EXPONENT =",a**b,"\n")
# Out:
# Enter a number =5
# Enter another number=8
# SUM = 13
#  DIFFERENCE = -3
#  PRODUCT = 40
#  DIVISION = 0.625
#  EXPONENT = 390625

# %%
import math
r = float(input("Enter the radius ="))
Area = math.pi*r*r
print(Area)
# Out:
# Enter the radius =1
# 3.141592653589793

# %%
import math
result1 = math.log10(10)
print(result1)
result2 = math.sin(math.pi/3)
print(result2)
# Out:
# 1.0
# 0.8660254037844386

# %%
a = int(input("ENTER A NUMBER"))
b = int(input("ENTER ANOTHER NUMBER"))
if a > b:
  print("a is greater than b")
else:
  print("a is less than b")
# Out:
# ENTER A NUMBER34
# ENTER ANOTHER NUMBER78
# a is less than b
